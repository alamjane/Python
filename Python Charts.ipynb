# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = [1, 4, 8]
y = [2, 6, 10]

x1 = [12, 5, 8]
y1 = [3, 6 ,9]

plt.plot(x,y)
plt.plot(x1,y1)
plt.title('Info')
plt.legend(['this is X', 'this is Y'])
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
x = [1,2,3]
y = [1,4,9]
z = [10,5,0]
plt.plot(x,y)
plt.plot(x,z)
plt.title("Test Plot")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend(["this is y", "this is z"])
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

x = [1, 4, 8]
y = [2, 6, 10]

x1 = [7, 3, 9]
y1 = [12, 11, 13]

plt.bar(x,y, color='magenta')
plt.bar(x1,y1, color='green')


plt.title('Info')
plt.legend(['pehle plot', 'dusra plot'])
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.show()

# %%
slices = [95, 40, 60, 30, 15]
channel = ['News', 'Sports', 'Entertainment', 'Reality Show', 'Cartoon']
cols = ['red', 'green', 'b', 'k', 'y']

plt.pie(slices, labels = channel, colors=cols, explode=(0.08,0.08,0.08,0.08,0.08))
plt.show()

# %%
slices = [95, 40, 60, 30, 15]
channel = ['News', 'Sports', 'Entertainment', 'Reality Show', 'Cartoon']
cols = ['red', 'green', 'b', 'cyan', 'y']

plt.pie(slices, labels = channel,
        colors=cols, 
        explode=(0.06,0.06,0.06,0.06,0.06),
        startangle=120,
        shadow=True,
        autopct='%1.1f%%'
        )

plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
x = [1, 13, 23, 44, 88]
y = [3, 66, 21, 49, 55]

x1 = [4, 15, 38, 50, 100]
y1 = [2, 60, 15, 40, 70]

plt.plot(x,y)
plt.plot(x1,y1)
plt.legend(['this is XY', 'this is X1Y1'])
plt.title('Info')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.show()

# %%
x = [1, 3, 5, 7, 9]
y = [2, 4, 6, 8, 10]

x1 = [11, 13, 15, 17, 19]
y1 = [12, 14, 16, 18, 20]


plt.bar(x,y, color = 'magenta')
plt.bar(x1,y1, color = 'green')
plt.legend(['this is XY', 'this is X1Y1'])
plt.title('Info')

plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
slices = [90, 40, 100, 70, 50, 120]
Channel = ['Starplus', 'SonyTV', 'AajTak', 'StarCricket', 'WWE', 'SetMax']
cols = ['red', 'blue', 'cyan', 'yellow', 'brown', 'green']
plt.pie(slices, labels = Channel,
        colors=cols, 
        explode=(0.06,0.06,0.06,0.06,0.06, 0.06),
      
        autopct='%1.1f%%'
        )
plt.show()

# %%
x = [10, 15, 20, 5, 0]
y = [8, 14, 18, 2, 1]

x1 = [4, 12, 16, 19, 22 ]
y1 = [11, 22, 33, 44, 55]

plt.bar(x,y,  color = 'green')
plt.bar(x1,y1, color = 'brown')
plt.legend(['this is xy', 'this is x1y1'])
plt.title('Info')
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
blood_sugar = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
plt.hist(blood_sugar, rwidth=0.8)
# Out:
# (array([3., 3., 1., 0., 1., 1., 0., 2., 0., 2.]),
#  array([ 77. ,  84.3,  91.6,  98.9, 106.2, 113.5, 120.8, 128.1, 135.4,
#         142.7, 150. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(blood_sugar,rwidth=0.5,bins=4)
# Out:
# (array([7., 1., 2., 3.]),
#  array([ 77.  ,  95.25, 113.5 , 131.75, 150.  ]),
#  <a list of 4 Patch objects>)

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")
blood_sugar_men = [113, 85, 90, 150, 149, 88, 93, 115, 135, 80, 77, 82, 129]
blood_sugar_women = [67, 98, 89, 120, 133, 150, 84, 69, 89, 79, 120, 112, 100]
plt.hist([blood_sugar_men,blood_sugar_women], bins=[80,100,125,150], rwidth=0.8, color=['green','orange'],label=['men','women'])
plt.legend()

# %%
plt.xlabel("Sugar Level")
plt.ylabel("Number Of Patients")
plt.title("Blood Sugar Chart")
plt.hist(blood_sugar,bins=[80,100,125,150],rwidth=0.95,histtype='step')
# Out:
# (array([6., 2., 4.]), array([ 80, 100, 125, 150]), <a list of 1 Patch objects>)

# %%
plt.xlabel("Number Of Patients")
plt.ylabel("Sugar Level")
plt.title("Blood Sugar Chart")
plt.hist(blood_sugar, bins=[80,100,125,150], rwidth=0.8, orientation='horizontal')
# Out:
# (array([6., 2., 4.]), array([ 80, 100, 125, 150]), <a list of 3 Patch objects>)

# %%
exp_vals = [1400,600,300,410,250]
exp_labels = ["Home Rent","Food","Phone/Internet Bill","Car ","Other Utilities"]

plt.axis("equal")
plt.pie(exp_vals,labels=exp_labels,radius=1, autopct='%1.1f%%', explode=[0,0.1,0.1,0,0])
plt.savefig("piechart.jpg", bbox_inches="tight", pad_inches=1, transparent=True)

# %%
import pandas as pd
from matplotlib import pyplot as plt
